# %% [markdown]
# ## 1. load data

# %%
import pandas as pd
# Out:
# /home/pi/.local/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
FILE = 'seafood_import_price.csv'

# %%
df = pd.read_csv(FILE)
df.head()
# Out:
#    SEQ_NO             STRD_DTM PRDCT_SCTN MNFCT_NTN_NM XPORT_NTN_NM  \
# 0     411  04-1월-2016 00:00:00        수산물         노르웨이         노르웨이
# 1     412  04-1월-2016 00:00:00        수산물          베트남          베트남
# 2     413  04-1월-2016 00:00:00        수산물           중국           중국
# 3     414  04-1월-2016 00:00:00        수산물         노르웨이         노르웨이
# 4     415  11-1월-2016 00:00:00        수산물       아랍에미리트       아랍에미리트
#
#   IMPORT_PRPS CTGRY_MLSFC_NM  SOF DETL_SOF IMPORT_FOM  AVE_UNPRC_AMT  \
# 0         판매용             어류  고등어      고등어         냉동              2
# 1         판매용       연체류 해물모듬  쭈꾸미      주꾸미         냉동              4
# 2         판매용         패류 멍게류  바지락      바지락          활              1
# 3         판매용             어류   연어       연어         냉장             10
# 4         판매용             어류   갈치       갈치         냉동              3
#
#      PHOTO_INFO_ESSN_ID
# 0  data/1607816233_aTFS
# 1  data/1607816233_aTFS
# 2  data/1607816233_aTFS
# 3  data/1607816233_aTFS
# ...

# %% [markdown]
# ## 2. 데이터 탐색

# %%
df.describe()
# Out:
#              SEQ_NO  AVE_UNPRC_AMT
# count  71449.000000   71449.000000
# mean   21287.556663      10.081121
# std    14730.614527      81.793454
# min        0.000000       0.000000
# 25%     8931.000000       3.000000
# 50%    17862.000000       5.000000
# 75%    33506.000000      10.000000
# max    51368.000000   20074.000000

# %%
# 칼럼
lst_col = ['PRDCT_SCTN', 'MNFCT_NTN_NM', 'XPORT_NTN_NM',
       'IMPORT_PRPS', 'CTGRY_MLSFC_NM', 'SOF', 'DETL_SOF', 'IMPORT_FOM']

# %%
# unique값 탐색하기
for i in lst_col:
    print(f'칼럼 : {i} \n값의개수 : {len(df[i].unique())} \n값의 종류 : {df[i].unique()}\n')
# Out:
# 칼럼 : PRDCT_SCTN
# 값의개수 : 1
# 값의 종류 : ['수산물']
#
# 칼럼 : MNFCT_NTN_NM
# 값의개수 : 95
# 값의 종류 : ['노르웨이' '베트남' '중국' '아랍에미리트' '아르헨티나' '호주' '캐나다' '칠레' '스페인' '인도네시아' '아일랜드'
#  '아이슬란드' '일본' '대한민국' '멕시코' '뉴질랜드' '페루' '파키스탄' '포르투갈' '러시아' '시에라리온' '세네갈'
#  '태국' '튀니지' '터키' '대만' '미국' '바누아투' '남아프리카 공화국' '바레인' '영국' '인도' '모로코'
#  '말레이시아' '필리핀' '프랑스' '모리타니' '에콰도르' '기니' '소말리아' '사우디아라비아' '리비아' '우루과이'
#  '세이셸' '이탈리아' '키리바시' '기니비사우' '브라질' '스리랑카' '불가리아' '피지' '우크라이나' '에스토니아' '이란'
#  '미얀마' '파푸아뉴기니' '가나' '방글라데시' '세인트빈센트 그레나딘' '파나마' '감비아' '크로아티아' '네덜란드'
#  '앙골라' '베네수엘라' '포클랜드 제도' '싱가포르' '몰타' '오만' '그리스' '그린란드' '알제리' '모잠비크' '이집트'
#  '수리남' '루마니아' '라트비아' '나미비아' '쿡 제도' '팔라우' '니카라과' '라이베리아' '마다가스카르' '쿠바'
#  '콜롬비아' '사이프러스' '미크로네시아 연방' '코트디부아르' '예멘' '덴마크' '콩고 민주 공화국' '통가' '탄자니아'
#  '몰디브' '페로 제도']
#
# 칼럼 : XPORT_NTN_NM
# 값의개수 : 95
# 값의 종류 : ['노르웨이' '베트남' '중국' '아랍에미리트' '태국' '일본' '칠레' '스페인' '인도네시아' '아일랜드' '아이슬란드'
#  '북한' '멕시코' '뉴질랜드' '페루' '파키스탄' '러시아' '시에라리온' '세네갈' '튀니지' '세이셸' '대만' '미국'
# ...

# %% [markdown]
# ## 3. 수입국가 분석
# - 카운트하기
# - 주요수입국가
# - 그래프로 나타내기

# %% [markdown]
# ## 4. 수입물품 분석
# - 가장 수입을 많이하는 제품
# - 가장 비싼 물품
# - 그래프로 나타내기
